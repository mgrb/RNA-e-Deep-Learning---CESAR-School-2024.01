# %%
import pandas as pd

# %%
df = pd.read_csv('PesquisaPerfis.csv')

# %%
list(df.columns)
# Out:
# ['Idade',
#  'Sexo',
#  'Região do Brasil (Local onde mora atualmente)',
#  'Classe Comportamental',
#  'Grau de Instrução',
#  'Estado Civil',
#  'Filhos',
#  'Qual tipo de surdez?',
#  'Tem implante coclear?',
#  'Usa aparelho auditivo?',
#  'Qual foi a primeira Língua?',
#  'Qual a língua de preferência?',
#  'Sabe Libras?',
#  'Quando aprendeu Libras?',
#  'Nível de Leitura em Português',
#  'Nível de Escrita em Português',
#  'Quando aprendeu Português?',
#  'Oraliza?',
#  'Faz leitura labial?',
#  'Como se comunica com a família?',
#  'Como se comunica com desconhecidos?',
#  'Como se comunica com amigos?',
#  'Usa algum app para se comunicar?',
#  'Usa legendas?',
#  'Compra em loja física?',
#  'Compra online?',
#  'Motivo de compra em loja física',
#  'Motivo de compra em loja online ',
#  'Preferência de Compra']

# %%
df.drop("Motivo de compra em loja física", axis = 1, inplace=True)
df.drop("Motivo de compra em loja online ", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    Idade Sexo Região do Brasil (Local onde mora atualmente)  \
# 0  26-30    F                                       Sudeste
# 1  26-30    F                                       Sudeste
# 2  21-25    M                                      Nordeste
# 3  41-45    M                                       Sudeste
# 4  31-35    M                                      Nordeste
#
#   Classe Comportamental                                  Grau de Instrução  \
# 0                     C  Superior completo (ou graduação): concluiu o c...
# 1                     C  Superior incompleto (ou graduação): não conclu...
# 2                     C  Superior incompleto (ou graduação): não conclu...
# 3                     B  Superior completo (ou graduação): concluiu o c...
# 4                     C  Superior completo (ou graduação): concluiu o c...
#
#     Estado Civil  Filhos Qual tipo de surdez? Tem implante coclear?  \
# 0  União Estável       1            Adquirida                   Não
# 1       Solteiro       0            Adquirida                   Não
# 2            NaN       0            Congênita                   Não
# 3       Solteiro       0            Congênita                   Sim
# 4       Solteiro       0            Adquirida                   Não
#
#      Usa aparelho auditivo?  ...            Oraliza? Faz leitura labial?  \
# 0                       Não  ...         Não Oraliza                 Sim
# 1                       Não  ...  Sim com familiares                 Sim
# 2  Já usou mas não usa mais  ...  Sim com familiares                 Sim
# 3  Já usou mas não usa mais  ...       Sim com todos                 Sim
# 4  Já usou mas não usa mais  ...  Sim com familiares                 Sim
#
#                     Como se comunica com a família?  \
# 0                        Português Escrito + LIBRAS
# 1  Português Escrito + Gestos Caseiros + Oralização
# 2           Português Escrito + LIBRAS + Oralização
# 3                    Português Escrito + Oralização
# 4  Português Escrito + Gestos Caseiros + Oralização
#
#                 Como se comunica com desconhecidos?  \
# 0                                 Português Escrito
# 1                        Português Escrito + LIBRAS
# 2                                 Português Escrito
# 3                    Português Escrito + Oralização
# 4  Português Escrito + Gestos Caseiros + Oralização
#
#   Como se comunica com amigos? Usa algum app para se comunicar? Usa legendas?  \
# 0                       LIBRAS                              Sim           Sim
# 1                       LIBRAS                              Sim           Sim
# 2                       LIBRAS                              Não           Sim
# 3          LIBRAS + Oralização                              Sim           Sim
# 4                       LIBRAS                              Sim           Sim
#
#   Compra em loja física? Compra online? Preferência de Compra
# 0                    Sim            Não           Loja Física
# 1                    Sim            Sim                   NaN
# 2                    Sim            Não           Loja Física
# 3                    Sim            Sim           Loja Online
# 4                    Não            Sim           Loja Online
#
# [5 rows x 27 columns]

# %%
from sklearn import preprocessing

df_norm = df.copy()
scaler = preprocessing.MinMaxScaler()
df_norm[['Filhos']] = scaler.fit_transform(df_norm[['Filhos']])

# %%
df_encoded = pd.get_dummies(df_norm, columns=['Idade', 'Sexo', 'Região do Brasil (Local onde mora atualmente)',
       'Classe Comportamental', 'Grau de Instrução', 'Estado Civil',
       'Qual tipo de surdez?', 'Tem implante coclear?',
       'Usa aparelho auditivo?', 'Qual foi a primeira Língua?',
       'Qual a língua de preferência?', 'Sabe Libras?',
       'Quando aprendeu Libras?', 'Nível de Leitura em Português',
       'Nível de Escrita em Português', 'Quando aprendeu Português?',
       'Oraliza?', 'Faz leitura labial?', 'Como se comunica com a família?',
       'Como se comunica com desconhecidos?', 'Como se comunica com amigos?',
       'Usa algum app para se comunicar?', 'Usa legendas?',
       'Compra em loja física?', 'Compra online?', 'Preferência de Compra'])

# %%
df_encoded.head()
# Out:
#    Filhos  Idade_21-25  Idade_26-30  Idade_31-35  Idade_36-40  Idade_41-45  \
# 0     0.5        False         True        False        False        False
# 1     0.0        False         True        False        False        False
# 2     0.0         True        False        False        False        False
# 3     0.0        False        False        False        False         True
# 4     0.0        False        False         True        False        False
#
#    Idade_51-55  Sexo_F  Sexo_M  \
# 0        False    True   False
# 1        False    True   False
# 2        False   False    True
# 3        False   False    True
# 4        False   False    True
#
#    Região do Brasil (Local onde mora atualmente)_Centro-Oeste  ...  \
# 0                                              False           ...
# 1                                              False           ...
# 2                                              False           ...
# 3                                              False           ...
# 4                                              False           ...
#
#    Usa algum app para se comunicar?_Sim  Usa legendas?_Não  Usa legendas?_Sim  \
# 0                                  True              False               True
# 1                                  True              False               True
# 2                                 False              False               True
# 3                                  True              False               True
# 4                                  True              False               True
#
#    Compra em loja física?_Não  Compra em loja física?_Sim  Compra online?_Não  \
# 0                       False                        True                True
# 1                       False                        True               False
# 2                       False                        True                True
# 3                       False                        True               False
# 4                        True                       False               False
#
#    Compra online?_Sim  Preferência de Compra_Loja Física  \
# 0               False                               True
# 1                True                              False
# 2               False                               True
# 3                True                              False
# 4                True                              False
#
#    Preferência de Compra_Loja Física + Loja Online  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    Preferência de Compra_Loja Online
# 0                              False
# 1                              False
# 2                              False
# 3                               True
# 4                               True
#
# [5 rows x 77 columns]

# %% [markdown]
# ## Elbow Method (clustering)
# In cluster analysis, the **elbow method** is a heuristic used in determining the number of clusters in a data set. The method consists of plotting the explained variation as a function of the number of clusters and picking the elbow of the curve as the number of clusters to use. The same method can be used to choose the number of parameters in other data-driven models, such as the number of principal components to describe a data set.
#
# The method can be traced to speculation by [Robert L. Thorndike in 1953](https://link.springer.com/article/10.1007/BF02289263).
#
# ![elbow method](https://raw.githubusercontent.com/vcasadei/images/master/DataClustering_ElbowCriterion.jpg)
#
# Using the "elbow" or "knee of a curve" as a cutoff point is a common heuristic in mathematical optimization to choose a point where diminishing returns are no longer worth the additional cost. In clustering, this means one should choose a number of clusters so that adding another cluster doesn't give much better modeling of the data.
#
# The intuition is that increasing the number of clusters will naturally improve the fit (explain more of the variation), since there are more parameters (more clusters) to use, but that at some point this is over-fitting, and the elbow reflects this. For example, given data that actually consist of k labeled groups – for example, k points sampled with noise – clustering with more than k clusters will "explain" more of the variation (since it can use smaller, tighter clusters), but this is over-fitting, since it is subdividing the labeled groups into multiple clusters. The idea is that the first clusters will add much information (explain a lot of variation), since the data actually consist of that many groups (so these clusters are necessary), but once the number of clusters exceeds the actual number of groups in the data, the added information will drop sharply, because it is just subdividing the actual groups. Assuming this happens, there will be a sharp elbow in the graph of explained variation versus clusters: increasing rapidly up to k (under-fitting region), and then increasing slowly after k (over-fitting region).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

Sum_of_squared_distances = []
K = range(1,14)
for num_clusters in K :
 kmeans = KMeans(n_clusters=num_clusters,n_init=100, max_iter=1000, algorithm='elkan', random_state = 0)
 kmeans.fit(df_encoded)
 Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,'bx-')
plt.xlabel('Values of K')
plt.ylabel('Sum of squared distances/Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# /home/mgrb/Workspaces/CESAR/RNA_DeepLearning/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1418: RuntimeWarning: algorithm='elkan' doesn't make sense for a single cluster. Using 'lloyd' instead.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,n_init=100, max_iter=10000, algorithm='elkan', random_state = 0)
clusters = kmeans.fit_predict(df_encoded)
labels = pd.DataFrame(clusters)
labeledCustomers = pd.concat((df,labels),axis=1)
labeledCustomers = labeledCustomers.rename({0:'labels'},axis=1)

# %%
def highlight_greaterthan_1(s):
  # print(s.labels)
  if s.labels == 0:
    return ['background-color: red']*28
  elif s.labels == 1:
    return ['background-color: green']*28
  else:
    return ['background-color: blue']*28


labeledCustomers.style.apply(highlight_greaterthan_1, axis=1)
# Out:
# <style type="text/css">
# #T_bfed7_row0_col0, #T_bfed7_row0_col1, #T_bfed7_row0_col2, #T_bfed7_row0_col3, #T_bfed7_row0_col4, #T_bfed7_row0_col5, #T_bfed7_row0_col6, #T_bfed7_row0_col7, #T_bfed7_row0_col8, #T_bfed7_row0_col9, #T_bfed7_row0_col10, #T_bfed7_row0_col11, #T_bfed7_row0_col12, #T_bfed7_row0_col13, #T_bfed7_row0_col14, #T_bfed7_row0_col15, #T_bfed7_row0_col16, #T_bfed7_row0_col17, #T_bfed7_row0_col18, #T_bfed7_row0_col19, #T_bfed7_row0_col20, #T_bfed7_row0_col21, #T_bfed7_row0_col22, #T_bfed7_row0_col23, #T_bfed7_row0_col24, #T_bfed7_row0_col25, #T_bfed7_row0_col26, #T_bfed7_row0_col27, #T_bfed7_row2_col0, #T_bfed7_row2_col1, #T_bfed7_row2_col2, #T_bfed7_row2_col3, #T_bfed7_row2_col4, #T_bfed7_row2_col5, #T_bfed7_row2_col6, #T_bfed7_row2_col7, #T_bfed7_row2_col8, #T_bfed7_row2_col9, #T_bfed7_row2_col10, #T_bfed7_row2_col11, #T_bfed7_row2_col12, #T_bfed7_row2_col13, #T_bfed7_row2_col14, #T_bfed7_row2_col15, #T_bfed7_row2_col16, #T_bfed7_row2_col17, #T_bfed7_row2_col18, #T_bfed7_row2_col19, #T_bfed7_row2_col20, #T_bfed7_row2_col21, #T_bfed7_row2_col22, #T_bfed7_row2_col23, #T_bfed7_row2_col24, #T_bfed7_row2_col25, #T_bfed7_row2_col26, #T_bfed7_row2_col27, #T_bfed7_row5_col0, #T_bfed7_row5_col1, #T_bfed7_row5_col2, #T_bfed7_row5_col3, #T_bfed7_row5_col4, #T_bfed7_row5_col5, #T_bfed7_row5_col6, #T_bfed7_row5_col7, #T_bfed7_row5_col8, #T_bfed7_row5_col9, #T_bfed7_row5_col10, #T_bfed7_row5_col11, #T_bfed7_row5_col12, #T_bfed7_row5_col13, #T_bfed7_row5_col14, #T_bfed7_row5_col15, #T_bfed7_row5_col16, #T_bfed7_row5_col17, #T_bfed7_row5_col18, #T_bfed7_row5_col19, #T_bfed7_row5_col20, #T_bfed7_row5_col21, #T_bfed7_row5_col22, #T_bfed7_row5_col23, #T_bfed7_row5_col24, #T_bfed7_row5_col25, #T_bfed7_row5_col26, #T_bfed7_row5_col27, #T_bfed7_row6_col0, #T_bfed7_row6_col1, #T_bfed7_row6_col2, #T_bfed7_row6_col3, #T_bfed7_row6_col4, #T_bfed7_row6_col5, #T_bfed7_row6_col6, #T_bfed7_row6_col7, #T_bfed7_row6_col8, #T_bfed7_row6_col9, #T_bfed7_row6_col10, #T_bfed7_row6_col11, #T_bfed7_row6_col12, #T_bfed7_row6_col13, #T_bfed7_row6_col14, #T_bfed7_row6_col15, #T_bfed7_row6_col16, #T_bfed7_row6_col17, #T_bfed7_row6_col18, #T_bfed7_row6_col19, #T_bfed7_row6_col20, #T_bfed7_row6_col21, #T_bfed7_row6_col22, #T_bfed7_row6_col23, #T_bfed7_row6_col24, #T_bfed7_row6_col25, #T_bfed7_row6_col26, #T_bfed7_row6_col27, #T_bfed7_row7_col0, #T_bfed7_row7_col1, #T_bfed7_row7_col2, #T_bfed7_row7_col3, #T_bfed7_row7_col4, #T_bfed7_row7_col5, #T_bfed7_row7_col6, #T_bfed7_row7_col7, #T_bfed7_row7_col8, #T_bfed7_row7_col9, #T_bfed7_row7_col10, #T_bfed7_row7_col11, #T_bfed7_row7_col12, #T_bfed7_row7_col13, #T_bfed7_row7_col14, #T_bfed7_row7_col15, #T_bfed7_row7_col16, #T_bfed7_row7_col17, #T_bfed7_row7_col18, #T_bfed7_row7_col19, #T_bfed7_row7_col20, #T_bfed7_row7_col21, #T_bfed7_row7_col22, #T_bfed7_row7_col23, #T_bfed7_row7_col24, #T_bfed7_row7_col25, #T_bfed7_row7_col26, #T_bfed7_row7_col27, #T_bfed7_row9_col0, #T_bfed7_row9_col1, #T_bfed7_row9_col2, #T_bfed7_row9_col3, #T_bfed7_row9_col4, #T_bfed7_row9_col5, #T_bfed7_row9_col6, #T_bfed7_row9_col7, #T_bfed7_row9_col8, #T_bfed7_row9_col9, #T_bfed7_row9_col10, #T_bfed7_row9_col11, #T_bfed7_row9_col12, #T_bfed7_row9_col13, #T_bfed7_row9_col14, #T_bfed7_row9_col15, #T_bfed7_row9_col16, #T_bfed7_row9_col17, #T_bfed7_row9_col18, #T_bfed7_row9_col19, #T_bfed7_row9_col20, #T_bfed7_row9_col21, #T_bfed7_row9_col22, #T_bfed7_row9_col23, #T_bfed7_row9_col24, #T_bfed7_row9_col25, #T_bfed7_row9_col26, #T_bfed7_row9_col27, #T_bfed7_row10_col0, #T_bfed7_row10_col1, #T_bfed7_row10_col2, #T_bfed7_row10_col3, #T_bfed7_row10_col4, #T_bfed7_row10_col5, #T_bfed7_row10_col6, #T_bfed7_row10_col7, #T_bfed7_row10_col8, #T_bfed7_row10_col9, #T_bfed7_row10_col10, #T_bfed7_row10_col11, #T_bfed7_row10_col12, #T_bfed7_row10_col13, #T_bfed7_row10_col14, #T_bfed7_row10_col15, #T_bfed7_row10_col16, #T_bfed7_row10_col17, #T_bfed7_row10_col18, #T_bfed7_row10_col19, #T_bfed7_row10_col20, #T_bfed7_row10_col21, #T_bfed7_row10_col22, #T_bfed7_row10_col23, #T_bfed7_row10 ...
#   background-color: blue;
# }
# #T_bfed7_row1_col0, #T_bfed7_row1_col1, #T_bfed7_row1_col2, #T_bfed7_row1_col3, #T_bfed7_row1_col4, #T_bfed7_row1_col5, #T_bfed7_row1_col6, #T_bfed7_row1_col7, #T_bfed7_row1_col8, #T_bfed7_row1_col9, #T_bfed7_row1_col10, #T_bfed7_row1_col11, #T_bfed7_row1_col12, #T_bfed7_row1_col13, #T_bfed7_row1_col14, #T_bfed7_row1_col15, #T_bfed7_row1_col16, #T_bfed7_row1_col17, #T_bfed7_row1_col18, #T_bfed7_row1_col19, #T_bfed7_row1_col20, #T_bfed7_row1_col21, #T_bfed7_row1_col22, #T_bfed7_row1_col23, #T_bfed7_row1_col24, #T_bfed7_row1_col25, #T_bfed7_row1_col26, #T_bfed7_row1_col27, #T_bfed7_row3_col0, #T_bfed7_row3_col1, #T_bfed7_row3_col2, #T_bfed7_row3_col3, #T_bfed7_row3_col4, #T_bfed7_row3_col5, #T_bfed7_row3_col6, #T_bfed7_row3_col7, #T_bfed7_row3_col8, #T_bfed7_row3_col9, #T_bfed7_row3_col10, #T_bfed7_row3_col11, #T_bfed7_row3_col12, #T_bfed7_row3_col13, #T_bfed7_row3_col14, #T_bfed7_row3_col15, #T_bfed7_row3_col16, #T_bfed7_row3_col17, #T_bfed7_row3_col18, #T_bfed7_row3_col19, #T_bfed7_row3_col20, #T_bfed7_row3_col21, #T_bfed7_row3_col22, #T_bfed7_row3_col23, #T_bfed7_row3_col24, #T_bfed7_row3_col25, #T_bfed7_row3_col26, #T_bfed7_row3_col27, #T_bfed7_row4_col0, #T_bfed7_row4_col1, #T_bfed7_row4_col2, #T_bfed7_row4_col3, #T_bfed7_row4_col4, #T_bfed7_row4_col5, #T_bfed7_row4_col6, #T_bfed7_row4_col7, #T_bfed7_row4_col8, #T_bfed7_row4_col9, #T_bfed7_row4_col10, #T_bfed7_row4_col11, #T_bfed7_row4_col12, #T_bfed7_row4_col13, #T_bfed7_row4_col14, #T_bfed7_row4_col15, #T_bfed7_row4_col16, #T_bfed7_row4_col17, #T_bfed7_row4_col18, #T_bfed7_row4_col19, #T_bfed7_row4_col20, #T_bfed7_row4_col21, #T_bfed7_row4_col22, #T_bfed7_row4_col23, #T_bfed7_row4_col24, #T_bfed7_row4_col25, #T_bfed7_row4_col26, #T_bfed7_row4_col27, #T_bfed7_row8_col0, #T_bfed7_row8_col1, #T_bfed7_row8_col2, #T_bfed7_row8_col3, #T_bfed7_row8_col4, #T_bfed7_row8_col5, #T_bfed7_row8_col6, #T_bfed7_row8_col7, #T_bfed7_row8_col8, #T_bfed7_row8_col9, #T_bfed7_row8_col10, #T_bfed7_row8_col11, #T_bfed7_row8_col12, #T_bfed7_row8_col13, #T_bfed7_row8_col14, #T_bfed7_row8_col15, #T_bfed7_row8_col16, #T_bfed7_row8_col17, #T_bfed7_row8_col18, #T_bfed7_row8_col19, #T_bfed7_row8_col20, #T_bfed7_row8_col21, #T_bfed7_row8_col22, #T_bfed7_row8_col23, #T_bfed7_row8_col24, #T_bfed7_row8_col25, #T_bfed7_row8_col26, #T_bfed7_row8_col27 {
#   background-color: green;
# }
# #T_bfed7_row11_col0, #T_bfed7_row11_col1, #T_bfed7_row11_col2, #T_bfed7_row11_col3, #T_bfed7_row11_col4, #T_bfed7_row11_col5, #T_bfed7_row11_col6, #T_bfed7_row11_col7, #T_bfed7_row11_col8, #T_bfed7_row11_col9, #T_bfed7_row11_col10, #T_bfed7_row11_col11, #T_bfed7_row11_col12, #T_bfed7_row11_col13, #T_bfed7_row11_col14, #T_bfed7_row11_col15, #T_bfed7_row11_col16, #T_bfed7_row11_col17, #T_bfed7_row11_col18, #T_bfed7_row11_col19, #T_bfed7_row11_col20, #T_bfed7_row11_col21, #T_bfed7_row11_col22, #T_bfed7_row11_col23, #T_bfed7_row11_col24, #T_bfed7_row11_col25, #T_bfed7_row11_col26, #T_bfed7_row11_col27, #T_bfed7_row12_col0, #T_bfed7_row12_col1, #T_bfed7_row12_col2, #T_bfed7_row12_col3, #T_bfed7_row12_col4, #T_bfed7_row12_col5, #T_bfed7_row12_col6, #T_bfed7_row12_col7, #T_bfed7_row12_col8, #T_bfed7_row12_col9, #T_bfed7_row12_col10, #T_bfed7_row12_col11, #T_bfed7_row12_col12, #T_bfed7_row12_col13, #T_bfed7_row12_col14, #T_bfed7_row12_col15, #T_bfed7_row12_col16, #T_bfed7_row12_col17, #T_bfed7_row12_col18, #T_bfed7_row12_col19, #T_bfed7_row12_col20, #T_bfed7_row12_col21, #T_bfed7_row12_col22, #T_bfed7_row12_col23, #T_bfed7_row12_col24, #T_bfed7_row12_col25, #T_bfed7_row12_col26, #T_bfed7_row12_col27 {
#   background-color: red;
# }
# </style>
# <table id="T_bfed7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfed7_level0_col0" class="col_heading level0 col0" >Idade</th>
#       <th id="T_bfed7_level0_col1" class="col_heading level0 col1" >Sexo</th>
#       <th id="T_bfed7_level0_col2" class=

# %%
labeledCustomers.to_csv('clusters.csv',encoding='utf-8-sig')
